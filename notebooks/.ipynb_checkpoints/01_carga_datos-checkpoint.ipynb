# %% [markdown]
# # <center> 1. Librerias

# %%
import sys
from pathlib import Path

# 1. Encontrar la raíz del proyecto (subir un nivel desde la carpeta 'notebooks')
# Si tu notebook está en la raíz, usá Path(".").resolve()
ROOT_DIR = Path("..").resolve()

# 2. Agregar la raíz al sistema de Python si no está cargada
if str(ROOT_DIR) not in sys.path:
    sys.path.append(str(ROOT_DIR))
    
import pandas as pd
import numpy as np
import openpyxl
from pathlib import Path
from src.preprocessing.common import format_df
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # <center> 2. Definicion de rutas

# %%
DATA_DIR = Path("../data/raw")
AUH_DIR = DATA_DIR / "AUH"
CBTA_DIR = DATA_DIR / "CBT-CBA"
IPC_DIR = DATA_DIR / "IPC"
EPH_DIR = DATA_DIR / "EPH"

# %% [markdown]
# # <center> 3. Carga y Ajuste de Estructura

# %% [markdown]
# ## <center> Cargamos AUH

# %%
hojas_auh = pd.read_excel(AUH_DIR/"AUH_data.xlsx", sheet_name=None)
hojas_auh
# Out:
# {'Boletín ': Empty DataFrame
#  Columns: []
#  Index: [],
#  'Contenido ':                                            Unnamed: 0  \
#  0   Boletín mensual de Asignaciones para Protecció...
#  1                                     Febrero de 2026
#  2                                                 NaN
#  3                                                 NaN
#  4                                           Contenido
#  5                                                 NaN
#  6                                    1. Beneficiarios
#  7                                                 1.1
#  8                                               1.1.A
#  9                                               1.1.B
#  10                                                1.2
#  11                                              1.2.A
#  12                                              1.2.B
#  13                                                1.3
#  14                                                1.4
#  15                                                1.5
#  16                                                1.6
#  17                                                1.7
#  18                                                1.8
#  19                                                1.9
#  20                                                NaN
#  21                                       2. Titulares
#  22                                                2.1
#  23                                                2.2
#  24                                                2.3
#  25                                                2.4
#  26                                                NaN
#  27                                          3. Montos
#  28                                                3.1
#  29                                                3.2
#  30                                                3.3
#  31                                                3.4
#  32                                                3.5
#  33                                                3.6
#  34                                                NaN
#  35                            4. Corresponsabilidades
#  36                                                4.1
#  37                                                NaN
#  38        5. Menores de 18 años en registros de ANSES
#  39                                                5.1
#  40                                                NaN
#  41                      6. Eficiencia de la cobertura
#  42                                                6.1
#  43                                                6.2
#  44                                                6.3
#
#                                             Unnamed: 1
#  0                                                 NaN
#  1                                                 NaN
#  2                                                 NaN
#  3                                                 NaN
#  4                                                 NaN
#  5                                                 NaN
#  6                                                 NaN
#  7   Beneficiarios de la Asignación Universal por H...
#  8   Beneficiarios de la Asignación Universal por H...
#  9   Beneficiarios de la Asignación Universal por H...
#  10  Beneficiarios de la Asignación Universal por H...
#  11  Beneficiarios de la Asignación Universal por H...
#  12  Beneficiarios de la Asignación Universal por H...
#  13  Beneficiarios de la Asignación Universal por H...
#  14  Beneficiarios de la Asignación Universal por H...
#  15  Beneficiarios de la Asignación por Hijo del Si...
#  16  Población total menor de 18 años en el Adminis...
#  17  Menores de 18 años en el Administrador de Dato...
#  18  Beneficiarios de la Asignación por Embarazo, p...
#  19  Beneficiarios del Apoyo Alimentario - Ley 1000...
#  20                                                NaN
#  21                                                NaN
#  22  Titulares de la Asignación Universal por Hijo ...
#  23  Titulares de la Asignación Universal por Hijo ...
#  24  Titulares de la Asignación Universal por Hijo ...
#  25  Titulares del Apoyo Alimentario - Ley 1000 Día...
#  26                                                NaN
#  27                                                NaN
#  28  Montos liquidados, en miles de pesos, de la As...
#  29  Montos liquidados, en miles de pesos, de la As...
#  30  Montos liquidados, en miles de pesos, de la As...
#  31  Montos liquidados, en miles de pesos, del Apoy...
#  32  Valor general, en pesos corrientes, de la Asig...
#  33  Valor general de la Asignación Universal por H...
#  34                                                NaN
#  35                                                NaN
#  36  Beneficiarios con corresponsabilidades cumplidas.
#  37                                                NaN
#  38                                                NaN
#  39  Cantidad de menores de 18 años con registros c...
#  40                                                NaN
#  41                                                NaN
#  42  Tiempo promedio, en semanas, que las beneficia...
#  43  Proporción de beneficiarias de la Asignación p...
#  44  Proporción de beneficiarios de la Asignación U...  ,
#  'Consideraciones - Definiciones':                                            Unnamed: 0
#  0   Boletín mensual de Asignaciones para Protecció...
#  1                                                 NaN
#  2                                        Definiciones
#  3                                                 NaN
#  4                       ASIGNACIÓN UNIVERSAL POR HIJO
#  5                                                 NaN
#  6   Beneficiarios: se consideran los niños, adoles...
#  7                                                 NaN
#  8   Montos liquidados: se consideran los montos de...
#  9                                                 NaN
#  10  Titulares:  persona que recibe la asignación e...
#  11                                                NaN
#  12  Valor general de la prestación: monto del 100%...
#  13                                                NaN
#  14     Periodo: corresponde al mes de la liquidación.
#  15                                                NaN
#  16  Corresponsabilidades: la asignación incluye co...
#  17                                                NaN
#  18                                                NaN
#  19                            ASIGNACIÓN POR EMBARAZO
#  20                                                NaN
#  21  Beneficiaria: corresponde a la embarazada a la...
#  22                                                NaN
#  23  Montos liquidados: se consideran los montos de...
#  24                                                NaN
#  25  Valor general de la prestación: monto del 100%...
#  26                                                NaN
#  27     Periodo: corresponde al mes de la liquidación.
#  28                                                NaN
#  29  Tiempo promedio de cobertura: corresponde a la...
#  30                                                NaN
#  31                                                NaN
#  32                  APOYO ALIMENTARIO - LEY 1000 DÍAS
#  33                                                NaN
#  34  Beneficiarios: niños y niñas beneficiarios de ...
#  35                                                NaN
#  36  Titulares: persona que recibe la asignación en...
#  37                                                NaN
#  38     Periodo: corresponde al mes de la liquidación.
#  39                                                NaN
#  40                                                NaN
#  41                                                NaN
#  42                                                NaN
#  43                                                NaN
#  44                          Consideraciones generales
#  45                                                NaN
#  46  A partir de junio de 2019 ANSES implementó el ...
#  47  Hasta ese momento la liquidación de las asigna...
#  48  Por este motivo, en esta publicación se presen...
#  49  Entre las mejoras introducidas por CUNA, se de...
#  50  Asimismo, en los sistemas anteriores se regist...
#  51  La información de asignaciones familiares (con...,
#  '1.1 Benef. H Edad':    Cuadro 1.1 - Beneficiarios de la Asignación Universal por Hijo, por mes, según edad simple  \
#  0                                                 NaN
#  1                                             Periodo
#  2                                                 NaN
#  3                                 2016-12-01 00:00:00
#  4                                 2017-12-01 00:00:00
#  5                                 2018-12-01 00:00:00
#  6                                 2019-12-01 00:00:00
#  7                                 2020-12-01 00:00:00
#  8                                 2021-12-01 00:00:00
#  9                                 2022-12-01 00:00:00
#  10                                2023-12-01 00:00:00
#  11                                2024-01-01 00:00:00
#  12                                2024-02-01 00:00:00
#  13                                2024-03-01 00:00:00
#  0                                                 NaN
#  1                                             Periodo
#  2                                 2024-12-01 00:00:00
#  3                                 2025-01-01 00:00:00
#  4                                 2025-02-01 00:00:00
#  5                                 2025-03-01 00:00:00
#  6                                 2025-04-01 00:00:00
#  7                                 2025-05-01 00:00:00
#  8                                 2025-06-01 00:00:00
#  9                                 2025-07-01 00:00:00
#  10                                2025-08-01 00:00:00
#  11                                2025-09-01 00:00:00
#  12                                2025-10-01 00:00:00
#  13                                2025-11-01 00:00:00
#  14                                2025-12-01 00:00:00
#  15                                2026-01-01 00:00:00
#  16                                2026-02-01 00:00:00
#  17  (1) La información del Ministerio de Salud lle...
#  18                                                NaN
#  19  Nota: el periodo corresponde al mes de liquida...
#  20                                                NaN
#  21                                     Fuente: ANSES
#
#     Unnamed: 1  Unnamed: 2   Unnamed: 3  Volver al índice
#  0         NaN         NaN          NaN               NaN
#  1         NaN  Automático  Inscripción               NaN
#  2         NaN        6.36        93.64               NaN
#  3         NaN        5.57        94.43               NaN
#  4         NaN        6.37        93.63               NaN
#  5         NaN        7.11        92.89               NaN
#  6         NaN        7.03        92.97               NaN
#  7         (1)        4.34        95.66               NaN
#  8         NaN        6.86        93.14               NaN
#  9         NaN         6.4         93.6               NaN
#  10        NaN        6.78        93.22               NaN
#  11        NaN        7.35        92.65               NaN
#  12        NaN         7.3         92.7               NaN
#  13        NaN        9.22        90.78               NaN
#  14        NaN       11.07        88.93               NaN
#  15        NaN       11.88        88.12               NaN
#  16        NaN       12.46        87.54               NaN
#  17        NaN         NaN          NaN               NaN
#  18        NaN         NaN          NaN               NaN
#  19        NaN         NaN          NaN               NaN
#  20        NaN         NaN          NaN               NaN
#  21        NaN         NaN          NaN               NaN  ,
#  '6.3 Corresponsabilidad automáti':   Cuadro 6.3 - Proporción de beneficiarios de la Asignación Universal por Hijo e Hijo con discapacidad de hasta 48 meses según forma de acreditación del cumplimiento de corresponsabilidad, por mes  \
#  0                                                NaN
#  1                                            Periodo
#  2                                2026-01-01 00:00:00
#  3                                2026-02-01 00:00:00
#  4                                                NaN
#  5  Nota: el periodo corresponde al mes de liquida...
#  6                                                NaN
#  7                                                NaN
#  8                                     Fuente: ANSES
#
#     Unnamed: 1     Unnamed: 2  Volver al índice
#  0         NaN            NaN               NaN
#  1  Automático  No automático               NaN
#  2    0.302143       0.697857               NaN
#  3      0.2895         0.7105               NaN
#  4         NaN            NaN               NaN
#  5         NaN            NaN               NaN
#  6         NaN            NaN               NaN
#  7         NaN            NaN               NaN
#  8         NaN            NaN               NaN  }

# %%
nombres_hojas = list(hojas_auh.keys())
print(f"Hojas encontradas en el archivo de AUH: {nombres_hojas}\n")
# Out:
# Hojas encontradas en el archivo de AUH: ['Boletín ', 'Contenido ', 'Consideraciones - Definiciones', '1.1 Benef. H Edad', '1.1.A Benef. H Muj Edad ', '1.1.B Benef. H Var Edad', '1.2 Benef. HD Edad', '1.2.A Benef. HD Muj Edad', '1.2.B Benef. HD Var Edad', '1.3 Benef. Ciclo Lect', '1.4 Benef. Situ. Mayor', '1.5 SUAF x sexo', '1.6 Población ', '1.7 Apertura otras incompatib', '1.8 Benef AxE', '1.9 Benef Apoyo Alimentario', '2.1 Titu. Sexo', '2.2 Titu Edad', '2.3 Hijos por Titu', '2.4 Titu Apoyo Alimentario', '3.1 Importes Liq.', '3.2 Importes Liq. SUAF', '3.3 Importes Liq AxE', '3.4 Importes Liq. Apoyo Alim', '3.5 Valor general pago', '3.6 Valor general-$ Feb 26', '4.1 Corresponsabilidades', '5.1 Indicador', '6.1 Tiempo Prom Cob', '6.2 Benef AxE forma acceso', '6.3 Corresponsabilidad automáti']

# %% [markdown]
# ## Vemos que tenemos multiples hojas, nos quedamos solo con las que nos hagan falta.

# %% [markdown]
# ### Valores generales de la AUH:

# %%
hojas_auh['3.5 Valor general pago'].head()
# Out:
#   Cuadro 3.5 - Valor general, en pesos corrientes, de la Asignación Universal por Hijo e Hijo con Discapacidad, de la Asignación por embarazo y del Apoyo Alimentario - Ley 1000 días   \
# 0                                                NaN
# 1                                            Periodo
# 2                                2009-10-01 00:00:00
# 3                                2010-10-01 00:00:00
# 4                                2011-05-01 00:00:00
#
#   Unnamed: 1             Unnamed: 2               Unnamed: 3  \
# 0        NaN                    NaN                      NaN
# 1       Hijo  Hijo con Discapacidad  Asignación por Embarazo
# 2        180                    720                      NaN
# 3        220                    880                      NaN
# 4        220                    880                      220
#
#                           Unnamed: 4  Volver al índice
# 0                                NaN               NaN
# 1  Apoyo Alimentario - Ley 1000 días               NaN
# 2                                NaN               NaN
# 3                                NaN               NaN
# 4                                NaN               NaN

# %% [markdown]
# ### Arreglemos la estructura:

# %%
df_AUH_valor_general = format_df('3.5 Valor general pago', hojas_auh, 2, -4, 1)

# %%
df_AUH_valor_general.head()
# Out:
# 1              Periodo Hijo Hijo con Discapacidad Asignación por Embarazo  \
# 0  2009-10-01 00:00:00  180                   720                     NaN
# 1  2010-10-01 00:00:00  220                   880                     NaN
# 2  2011-05-01 00:00:00  220                   880                     220
# 3  2011-09-01 00:00:00  270                  1080                     270
# 4  2012-09-01 00:00:00  340                  1200                     340
#
# 1 Apoyo Alimentario - Ley 1000 días
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN

# %% [markdown]
# ### Edades de los titulares del beneficio:

# %%
hojas_auh['2.2 Titu Edad'].tail()
# Out:
#    Cuadro 2.2 - Titulares de la Asignación Universal por Hijo por mes, según grupo de edad  \
# 36                                2026-02-01 00:00:00
# 37                                                NaN
# 38  Nota: el periodo corresponde al mes de liquida...
# 39                                                NaN
# 40                                      Fuente: ANSES
#
#    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 36      47631     250707     469085     536368     436850     309353
# 37        NaN        NaN        NaN        NaN        NaN        NaN
# 38        NaN        NaN        NaN        NaN        NaN        NaN
# 39        NaN        NaN        NaN        NaN        NaN        NaN
# 40        NaN        NaN        NaN        NaN        NaN        NaN
#
#    Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# 36     200084      88102      28329        4757         536         236
# 37        NaN        NaN        NaN         NaN         NaN         NaN
# 38        NaN        NaN        NaN         NaN         NaN         NaN
# 39        NaN        NaN        NaN         NaN         NaN         NaN
# 40        NaN        NaN        NaN         NaN         NaN         NaN
#
#    Unnamed: 13 Unnamed: 14 Unnamed: 15  Volver al índice
# 36        4721     2376759   34.257115               NaN
# 37         NaN         NaN         NaN               NaN
# 38         NaN         NaN         NaN               NaN
# 39         NaN         NaN         NaN               NaN
# 40         NaN         NaN         NaN               NaN

# %% [markdown]
# ### Arreglemos la estructura:

# %%
# 1. Seleccionamos las filas 1 y 2 (la fila 0 está vacía, no aporta datos)
encabezados = hojas_auh['2.2 Titu Edad'].iloc[1:3]

# 2. Fusionamos la fila 2 (rangos de edad) rellenando sus NaN con la fila 1 (Periodo, Total, etc.)
nuevas_columnas = encabezados.iloc[1].fillna(encabezados.iloc[0])

# 3. Asignamos los nombres resultantes como las columnas oficiales del DataFrame
hojas_auh['2.2 Titu Edad'].columns = nuevas_columnas

# 4. Eliminamos las filas de encabezado (0, 1 y 2) para dejar solo los datos numéricos abajo
df_AUH_edad_titular = hojas_auh['2.2 Titu Edad'].iloc[3:-4].reset_index(drop=True)
df_AUH_edad_titular = df_AUH_edad_titular.loc[:, df_AUH_edad_titular.columns.notna()]

# %%
df_AUH_edad_titular.tail()
# Out:
# 2               Periodo 15 - 19 20 - 24 25 - 29 30 - 34 35 - 39 40 - 44  \
# 29  2025-10-01 00:00:00   49257  256974  474493  530194  428984  305007
# 30  2025-11-01 00:00:00   48826  255570  473359  531912  431046  305653
# 31  2025-12-01 00:00:00   48429  254085  472109  534062  433524  307079
# 32  2026-01-01 00:00:00   47981  252126  470424  534868  434918  308168
# 33  2026-02-01 00:00:00   47631  250707  469085  536368  436850  309353
#
# 2  45 - 49 50 - 54 55 - 59 60 - 64 65 - 69 Más de 70 Sin datos    Total  \
# 29  195810   86289   27387    4434     510       232      4400  2363971
# 30  197222   86771   27654    4529     494       233      4489  2367758
# 31  198770   87309   27994    4573     520       231      4587  2373272
# 32  199169   87617   28102    4622     518       233      4570  2373316
# 33  200084   88102   28329    4757     536       236      4721  2376759
#
# 2  Edad Promedio
# 29     34.128514
# 30     34.160209
# 31     34.196781
# 32     34.225823
# 33     34.257115

# %% [markdown]
# ##  <center>Cargamos CBT Y CBA

# %%
CBA = pd.read_csv(CBTA_DIR/"canasta-basica-alimentaria-regiones-del-pais.csv")
CBT = pd.read_csv(CBTA_DIR/"canasta-basica-total-regiones-del-pais.csv")

# %% [markdown]
# ### Veamos los datos de la canasta basica alimentaria:

# %%
CBA.head()
# Out:
#   indice_tiempo  gran_buenos_aires     cuyo  noreste  noroeste  pampeana  \
# 0    2016-04-01            1514.53  1358.29  1371.62   1333.91   1514.96
# 1    2016-05-01            1561.35  1398.20  1404.27   1369.37   1562.75
# 2    2016-06-01            1614.32  1445.22  1447.63   1413.77   1614.33
# 3    2016-07-01            1666.48  1494.04  1496.21   1458.24   1660.19
# 4    2016-08-01            1675.05  1496.09  1501.91   1459.38   1662.99
#
#    patagonia
# 0    1556.96
# 1    1604.30
# 2    1661.42
# 3    1713.67
# 4    1723.86

# %%
CBA.tail()
# Out:
#     indice_tiempo  gran_buenos_aires       cuyo    noreste   noroeste  \
# 112    2025-08-01          168456.04  150019.85  149802.94  145932.54
# 113    2025-09-01          170788.46  152803.20  152566.11  148800.44
# 114    2025-10-01          176150.29  157636.84  157679.95  153475.78
# 115    2025-11-01          183289.46  163650.50  164584.23  159191.14
# 116    2025-12-01          190780.09  169325.29  171065.04  164555.21
#
#       pampeana  patagonia
# 112  165643.09  172540.84
# 113  168519.55  175412.47
# 114  174130.91  181342.77
# 115  181196.12  189380.65
# 116  188144.43  197032.47

# %%
CBT.head()
# Out:
#   indice_tiempo  gran_buenos_aires     cuyo  noreste  noroeste  pampeana  \
# 0    2016-04-01            3665.17  3504.40  3099.86   2987.95   3666.21
# 1    2016-05-01            3825.30  3649.31  3229.82   3122.17   3828.74
# 2    2016-06-01            3938.94  3757.58  3315.07   3209.27   3938.96
# 3    2016-07-01            4032.88  3854.62  3396.40   3281.04   4017.66
# 4    2016-08-01            4036.87  3844.95  3394.32   3269.01   4007.81
#
#    patagonia
# 0    4281.63
# 1    4459.96
# 2    4602.13
# 3    4712.59
# 4    4723.38

# %%
CBT.tail()
# Out:
#     indice_tiempo  gran_buenos_aires       cuyo    noreste   noroeste  \
# 112    2025-08-01          375656.97  355547.04  313088.14  302080.36
# 113    2025-09-01          380858.27  363671.62  318863.17  308016.91
# 114    2025-10-01          392815.15  375175.68  329551.10  317694.86
# 115    2025-11-01          406902.60  387851.69  342335.20  327933.75
# 116    2025-12-01          423531.80  399607.68  355815.28  338983.73
#
#       pampeana  patagonia
# 112  369384.09  436528.33
# 113  375798.60  445547.67
# 114  388311.93  458797.21
# 115  402255.39  477239.24
# 116  417680.63  496521.82

# %% [markdown]
# ### Estan correctos de estructura.

# %% [markdown]
# ## <center> Cargamos IPC

# %%
hojas_ipc = pd.read_excel(IPC_DIR/"ipc_nacional.xlsx", sheet_name=1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 hojas_ipc = pd.read_excel(IPC_DIR/"ipc_nacional.xlsx", sheet_name=1)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\io\excel\_base.py:482, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     480 if not isinstance(io, ExcelFile):
#     481     should_close = True
# --> 482     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     483 elif engine and engine != io.engine:
#     484     raise ValueError(
#     485         "Engine should not be specified when passing "
#     486         "an ExcelFile - ExcelFile already has the engine set"
#     487     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\io\excel\_base.py:1695, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1692 self.engine = engine
#    1693 self.storage_options = storage_options
# -> 1695 self._reader = self._engines[engine](self._io, storage_options=storage_options)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\io\excel\_openpyxl.py:557, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options)
#     547 """
#     548 Reader using openpyxl engine.
#     549
#    (...)
#     554 {storage_options}
#     555 """
#     556 import_optional_dependency("openpyxl")
# --> 557 super().__init__(filepath_or_buffer, storage_options=storage_options)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\io\excel\_base.py:545, in BaseExcelReader.__init__(self, filepath_or_buffer, storage_options)
#     543 self.handles.handle.seek(0)
#     544 try:
# --> 545     self.book = self.load_workbook(self.handles.handle)
#     546 except Exception:
#     547     self.close()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\io\excel\_openpyxl.py:568, in OpenpyxlReader.load_workbook(self, filepath_or_buffer)
#     565 def load_workbook(self, filepath_or_buffer: FilePath | ReadBuffer[bytes]):
#     566     from openpyxl import load_workbook
# --> 568     return load_workbook(
#     569         filepath_or_buffer, read_only=True, data_only=True, keep_links=False
#     570     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\openpyxl\reader\excel.py:348, in load_workbook(filename, read_only, keep_vba, data_only, keep_links, rich_text)
#     318 """Open the given filename and return the workbook
#     319
#     320 :param filename: the path to open or a file-like object
#    (...)
#     344
#     345 """
#     346 reader = ExcelReader(filename, read_only, keep_vba,
#     347                      data_only, keep_links, rich_text)
# --> 348 reader.read()
#     349 return reader.wb
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\openpyxl\reader\excel.py:301, in ExcelReader.read(self)
#     299 self.read_theme()
#     300 action = "read stylesheet"
# --> 301 apply_stylesheet(self.archive, self.wb)
#     302 action = "read worksheets"
#     303 self.read_worksheets()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\openpyxl\styles\stylesheet.py:213, in apply_stylesheet(archive, wb)
#     210     return wb
#     212 node = fromstring(src)
# --> 213 stylesheet = Stylesheet.from_tree(node)
#     215 if stylesheet.cell_styles:
#     217     wb._borders = IndexedList(stylesheet.borders)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\openpyxl\styles\stylesheet.py:105, in Stylesheet.from_tree(cls, node)
#     103 for k in attrs:
#     104     del node.attrib[k]
# --> 105 return super(Stylesheet, cls).from_tree(node)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\openpyxl\descriptors\serialisable.py:103, in Serialisable.from_tree(cls, node)
#     100     else:
#     101         attrib[tag] = obj
# --> 103 return cls(**attrib)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\openpyxl\styles\stylesheet.py:96, in Stylesheet.__init__(self, numFmts, fonts, fills, borders, cellStyleXfs, cellXfs, cellStyles, dxfs, tableStyles, colors, extLst)
#      94 self.protections = self.cellXfs.prots
#      95 self._normalise_numbers()
# ---> 96 self.named_styles = self._merge_named_styles()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\openpyxl\styles\stylesheet.py:118, in Stylesheet._merge_named_styles(self)
#     116 for style_ref in style_refs:
#     117     style = self._expand_named_style(style_ref)
# --> 118     named_styles.append(style)
#     120 return named_styles
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\openpyxl\styles\named_styles.py:175, in NamedStyleList.append(self, style)
#     173 if not isinstance(style, NamedStyle):
#     174     raise TypeError("""Only NamedStyle instances can be added""")
# --> 175 elif style.name in self.names:
#     176     raise ValueError("""Style {0} exists already""".format(style.name))
#     177 style._style.xfId = (len(self))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\openpyxl\styles\named_styles.py:158, in NamedStyleList.names(self)
#     156 @property
#     157 def names(self):
# --> 158     return [s.name for s in self]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\openpyxl\styles\named_styles.py:158, in <listcomp>(.0)
#     156 @property
#     157 def names(self):
# --> 158     return [s.name for s in self]
#
# KeyboardInterrupt:

# %%
# Abrimos el archivo en modo "solo lectura" estricto
wb = openpyxl.load_workbook(IPC_DIR / "ipc_nacional.xlsx", read_only=True, data_only=True)

# Pasamos ese libro directamente a Pandas
with pd.ExcelFile(wb) as xls:
    df_ipc = pd.read_excel(xls, sheet_name=1)

# Cerramos el libro para liberar la memoria
wb.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 2
#       1 # Abrimos el archivo en modo "solo lectura" estricto
# ----> 2 wb = openpyxl.load_workbook(IPC_DIR / "ipc_nacional.xlsx", read_only=True, data_only=True)
#       4 # Pasamos ese libro directamente a Pandas
#       5 with pd.ExcelFile(wb) as xls:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\openpyxl\reader\excel.py:348, in load_workbook(filename, read_only, keep_vba, data_only, keep_links, rich_text)
#     318 """Open the given filename and return the workbook
#     319
#     320 :param filename: the path to open or a file-like object
#    (...)
#     344
#     345 """
#     346 reader = ExcelReader(filename, read_only, keep_vba,
#     347                      data_only, keep_links, rich_text)
# --> 348 reader.read()
#     349 return reader.wb
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\openpyxl\reader\excel.py:301, in ExcelReader.read(self)
#     299 self.read_theme()
#     300 action = "read stylesheet"
# --> 301 apply_stylesheet(self.archive, self.wb)
#     302 action = "read worksheets"
#     303 self.read_worksheets()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\openpyxl\styles\stylesheet.py:213, in apply_stylesheet(archive, wb)
#     210     return wb
#     212 node = fromstring(src)
# --> 213 stylesheet = Stylesheet.from_tree(node)
#     215 if stylesheet.cell_styles:
#     217     wb._borders = IndexedList(stylesheet.borders)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\openpyxl\styles\stylesheet.py:105, in Stylesheet.from_tree(cls, node)
#     103 for k in attrs:
#     104     del node.attrib[k]
# --> 105 return super(Stylesheet, cls).from_tree(node)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\openpyxl\descriptors\serialisable.py:103, in Serialisable.from_tree(cls, node)
#     100     else:
#     101         attrib[tag] = obj
# --> 103 return cls(**attrib)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\openpyxl\styles\stylesheet.py:96, in Stylesheet.__init__(self, numFmts, fonts, fills, borders, cellStyleXfs, cellXfs, cellStyles, dxfs, tableStyles, colors, extLst)
#      94 self.protections = self.cellXfs.prots
#      95 self._normalise_numbers()
# ---> 96 self.named_styles = self._merge_named_styles()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\openpyxl\styles\stylesheet.py:118, in Stylesheet._merge_named_styles(self)
#     116 for style_ref in style_refs:
#     117     style = self._expand_named_style(style_ref)
# --> 118     named_styles.append(style)
#     120 return named_styles
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\openpyxl\styles\named_styles.py:177, in NamedStyleList.append(self, style)
#     175 elif style.name in self.names:
#     176     raise ValueError("""Style {0} exists already""".format(style.name))
# --> 177 style._style.xfId = (len(self))
#     178 super(NamedStyleList, self).append(style)
#
# KeyboardInterrupt:
